# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
t = np.arange(0,100,0.01)
t.size
# Out:
# 10000

# %%
x = np.arange(0,100,0.01)
x.size
# Out:
# 10000

# %%
plot (t,x,'r-')
xlabel('t [hs]')
ylabel('N [unidades arbitrarias]')
title('Decaimiento padre/hijo - Número de radionucleidos ')
legend('Linea')
xlim([1, 50]);
